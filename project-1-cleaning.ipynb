# %% [markdown]
# ## Project 1
# ##### Ebru Dagdelen
# ##### 10/4/2023-10/10/2023
# Assignment 5: Data Exploration and Cleaning with Python
# This notebook cleans the datafile that contains results of a survey conducted by CCM. Specifically this notebook cleans the CCM Computing Entry Survey - Fall 2022.csv file. The goal with doing so is to analyze the data and answer the following questions:
# 1. From those who answered likely to take another computing class(4 or 5) what is the distribution of the majors/departments they are enrolled as?
#
# 2. What are the demographic distribution of the data?(Age, Race/Ethinicity, Gender)
#
# 3. What percent of students were engaged with CCM(attended an event at CCM) prior to enrolling to CCM?
#
# 4. What percent of students received information about the computing programs/classes at CCM? What is the top information source?
#
# 5. What percent of students chose a computing major/certification as their first major? What are the distributions of previous CCM programs for those who changed to a computing major/certification?

# %%
#Import modules we might use.
import pandas as pd
import math
import statistics as stat

# %%
#Bring in the CSV file.
datafilecomputing = "/Users/ebrushka/Desktop/python/homeworks/project-1/entry.csv"
computing = pd.read_csv(datafilecomputing)

# %% [markdown]
# Let's first try to understand our datafile(We already have thoughts on it from examining in Excel.

# %%
computing.head()
# Out:
#                    Timestamp Which course are you enrolled in?  \
# 0  2022/09/26 1:13:34 PM AST        CMP 128 Computer Science I
# 1  2022/09/26 2:36:22 PM AST                               NaN
# 2  2022/09/26 2:37:38 PM AST        CMP 128 Computer Science I
# 3  2022/09/26 2:39:43 PM AST        CMP 128 Computer Science I
# 4  2022/09/26 2:40:07 PM AST        CMP 128 Computer Science I
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# ...

# %% [markdown]
# We have too many columns; let's take out those we don't want.

# %%
#Look at column names and only keep columns we want.
computing.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
#Keep columns that we want.
selected_columns = ['Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]','What degree program are you currently enrolled in?',
       'Did you receive information about the CCM computing programs from any of the following sources? [High school guidance counselor]',
       'Did you receive information about the CCM computing programs from any of the following sources? [High School Teacher]',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM Information Technologies Website]',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM Admissions]',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM advisor/counselor]',
       'Did you receive information about the CCM computing programs from any of the following sources? [Employer]',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]',
       'Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]',
       'Did you receive information about the CCM computing programs from any of the following sources? [Other]',
       'Gender','Race/ethnicity','Age ',
       'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?',
       'Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.']
computing_selected = computing[selected_columns]

# %% [markdown]
# Those column names are too long;let's rename them.

# %%
#Rename columns.
new_column_names = {'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]' : 'open_house',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]': 'instant_decision',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]': 'campus_info',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]': 'virtual_info',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]': 'women_whodare',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]': 'college_fair',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]': 'sharetime_info',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]': 'challenger',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]': 'cybersc_prog',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]': 'hs_info',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]': 'hscampus_visit',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]': 'ind_campus_visit',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]': 'worforce_class',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]': 'corporate_training',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]': 'teen_arts',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]': 'summer_camp',
       'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]': 'hour_code',
       'What degree program are you currently enrolled in?':'Major',
       'Did you receive information about the CCM computing programs from any of the following sources? [High school guidance counselor]': 'hs_councelor',
       'Did you receive information about the CCM computing programs from any of the following sources? [High School Teacher]': 'teacher',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM Information Technologies Website]' : 'IT_website',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM Admissions]': 'admissions',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM advisor/counselor]': 'CCM_advisor',
       'Did you receive information about the CCM computing programs from any of the following sources? [Employer]': 'employer',
       'Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]': 'ccmworforce',
       'Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]': 'njworkforce',
       'Did you receive information about the CCM computing programs from any of the following sources? [Other]': 'other',
       'Gender': 'gender','Race/ethnicity': 'race/ethnicity', 'Age ': 'age',
       'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?': 'intereset_rating',
       'Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.': 'first_major'}

computing_selected.rename(columns=new_column_names, inplace=True)
# Out:
# /var/folders/h2/x0c5whwn6rs3djfbtt9ywvnc0000gn/T/ipykernel_32534/2585597151.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   computing_selected.rename(columns=new_column_names, inplace=True)

# %%
#Let's take a look at what we have so far.
computing_selected.shape #we didn't lose any rows
computing_selected.head()#looks like everything worked
# Out:
#   open_house instant_decision campus_info virtual_info women_whodare  \
# 0        Yes               No         Yes          Yes            No
# 1         No               No          No           No            No
# 2         No               No          No           No            No
# 3        Yes               No         Yes          Yes            No
# 4         No               No          No           No            No
#
#   college_fair sharetime_info challenger cybersc_prog hs_info  ...  \
# 0           No             No         No           No     Yes  ...
# 1           No             No         No           No      No  ...
# 2           No             No        Yes           No     Yes  ...
# 3           No             No         No           No     Yes  ...
# 4           No             No         No           No      No  ...
#
#   CCM_advisor employer ccmworforce njworkforce other gender   race/ethnicity  \
# ...

# %%
computing_selected.columns #making sure there isn't any long column names left.
# Out:
# Index(['open_house', 'instant_decision', 'campus_info', 'virtual_info',
#        'women_whodare', 'college_fair', 'sharetime_info', 'challenger',
#        'cybersc_prog', 'hs_info', 'hscampus_visit', 'ind_campus_visit',
#        'worforce_class', 'corporate_training', 'teen_arts', 'summer_camp',
#        'hour_code', 'Major', 'hs_councelor', 'teacher', 'IT_website',
#        'admissions', 'CCM_advisor', 'employer', 'ccmworforce', 'njworkforce',
#        'other', 'gender', 'race/ethnicity', 'age', 'intereset_rating',
#        'first_major'],
#       dtype='object')

# %% [markdown]
# Now let's try to clean up our data by looking at the goal of our questions. We want to know if students attented any CCM events so we have to create a new column that will look at all columns related to events and fill in the new column accordingly.

# %%
#Let's create a new column that will tell us if a student attended ANY of the CCM events prior to enrolling at CCM.
event = ['open_house', 'instant_decision', 'campus_info', 'virtual_info',
       'women_whodare', 'college_fair', 'sharetime_info', 'challenger',
       'cybersc_prog', 'hs_info', 'hscampus_visit', 'ind_campus_visit',
       'worforce_class', 'corporate_training', 'teen_arts', 'summer_camp',
       'hour_code'] 
computing_selected['attended_event'] = 'No'

#I used stackoverflow to learn about iterrows: https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
#I didn't know about .at[] either, I kind of figured it out while reading different websites, here's one
# of them: https://www.geeksforgeeks.org/python-pandas-dataframe-at/
#If in any of the columns in event is Yes, then change the new column to say Yes to indicate the student 
#attented an event at CCM prior to enrollment.
for index, row in computing_selected.iterrows():
    for column in event:
        if row[column] == 'Yes':
            computing_selected.at[index, 'attended_event'] = 'Yes'
            break
# Out:
# /var/folders/h2/x0c5whwn6rs3djfbtt9ywvnc0000gn/T/ipykernel_32534/3209325529.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   computing_selected['attended_event'] = 'No'

# %% [markdown]
# Now let's do the same thing to see if students received information about the Technology department at CCM.

# %%
#Let's create a new column that will tell us if a student received ANY information about the technology 
#department at CCM prior to enrolling at CCM.
info = ['hs_councelor', 'teacher', 'IT_website',
       'admissions', 'CCM_advisor', 'employer', 'ccmworforce', 'njworkforce',
       'other'] 
computing_selected['received_info'] = 'No'

for index, row in computing_selected.iterrows():
    for column in info:
        if row[column] == 'Yes':
            computing_selected.at[index, 'received_info'] = 'Yes'
            break
# Out:
# /var/folders/h2/x0c5whwn6rs3djfbtt9ywvnc0000gn/T/ipykernel_32534/818753672.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   computing_selected['received_info'] = 'No'

# %%
#Now that we have the column that says if a student attented an event, we don't really need each individual 
#event(our questions do not ask the distribution) so lets subset again to remove exclude them from our data.
columns_staying = ['Major', 'hs_councelor', 'teacher', 'IT_website',
       'admissions', 'CCM_advisor', 'employer', 'ccmworforce', 'njworkforce',
       'other', 'gender', 'race/ethnicity', 'age', 'intereset_rating',
       'first_major', 'attended_event', 'received_info']

computing_selected = computing_selected[columns_staying]
computing_selected.columns #Looks like we're left with the columns we need to answer our questions.
# Out:
# Index(['Major', 'hs_councelor', 'teacher', 'IT_website', 'admissions',
#        'CCM_advisor', 'employer', 'ccmworforce', 'njworkforce', 'other',
#        'gender', 'race/ethnicity', 'age', 'intereset_rating', 'first_major',
#        'attended_event', 'received_info'],
#       dtype='object')

# %% [markdown]
# Let's continue cleaning our data. The race/ethnicity is one to take a look at.

# %%
#Let's take a look at the race/ethnicity column.
computing_selected['race/ethnicity'].unique() #We have a lot of multi-racial students.
# Out:
# array(['White/Caucasian', 'Asian', 'Choose not to reply',
#        'Hispanic or Latino;White/Caucasian', 'Hispanic or Latino',
#        'American Indian/Native American/Alaska Native', 'Multi-Racial',
#        'American Indian/Native American/Alaska Native;Multi-Racial',
#        'Black/African American;White/Caucasian;Multi-Racial',
#        'Black/African American',
#        'Hispanic or Latino;American Indian/Native American/Alaska Native;Asian;Black/African American;Native Hawaiian/Other Pacific Islander;White/Caucasian',
#        'Hispanic or Latino;Black/African American',
#        'White/Caucasian;Multi-Racial',
#        'Asian;Native Hawaiian/Other Pacific Islander;White/Caucasian',
#        'Asian;White/Caucasian', 'Hispanic or Latino;Multi-Racial',
#        'Hispanic or Latino;American Indian/Native American/Alaska Native;White/Caucasian;Multi-Racial',
#        'American Indian/Native American/Alaska Native;Native Hawaiian/Other Pacific Islander;Multi-Racial',
# ...

# %%
#We can realize that if a student is multi-racial, the races are seperated by ;. So let's create a mask that if a 
#row in the column has ;, we will change the row to Multi-Racial.
mask = computing_selected['race/ethnicity'].str.contains(';')
computing_selected.loc[mask, 'race/ethnicity'] = 'Multi-Racial'

# %%
#Let's see if this worked.
computing_selected['race/ethnicity'].unique() #Woop Woop!!!!
# Out:
# array(['White/Caucasian', 'Asian', 'Choose not to reply', 'Multi-Racial',
#        'Hispanic or Latino',
#        'American Indian/Native American/Alaska Native',
#        'Black/African American'], dtype=object)

# %% [markdown]
# Now let's clean up major and first major. We see that since there was a free-response section that there are long responses alongside with typos, empty spaces etc.

# %%
#Have to clean major and first major
computing_selected['Major'].unique() #Lets try to clean this up.
# Out:
# array(['Computer Science', 'Liberal Arts', 'Information Technology',
#        'Academy Student', 'Business Administration ', 'Liberal arts',
#        'I am still a senior in high school (Morris County School of Technology) and my school offers a program that allows you to attend a CCM class or classes',
#        'Music Recording ', 'Bio ', 'Mechanical engineering technology',
#        'Mathematics', 'Mechanical Engineering', 'Electronics Engineering',
#        'Mechanical Engineering ', 'CIS Game Development Option',
#        'Finance/Business ', 'Challenger Program', 'Non Degree seeking',
#        'Technical Studies, Applied Associate of Science',
#        'Changed to Business ', 'Mechanical Engineering Technology',
#        'mechanical engineering technology', 'edam',
#        'Share Time Engineering',
#        'Engineering Design and Manufacturing (Time Share)', 'Psychology',
#        'Undecided', 'dont have one', 'Share time engineering',
# ...

# %% [markdown]
# I initially tried to do this by using masks but quickly went down a spiral of trying to figure out what masks to create. So I got helped from chatGPT with how to most affectively clean this data. I will attach a word document with the prompt I gave chatGPT and the response it printed out. How it approached it was by using mapping and creating a new column in the dataset to store the cleaned(renamed) rows. I overwrite the old column to avoid adding more columns to my dataset.

# %%
major_mapping = {
    'Computer Science': 'Computer Science', 'Liberal Arts' : 'Liberal Arts', 'Information Technology' : 'Information Technology',
       'Academy Student':'High School Student', 'Business Administration ': 'Business Administration', 
       'Liberal arts': 'Liberal Arts',
       'I am still a senior in high school (Morris County School of Technology) and my school offers a program that allows you to attend a CCM class or classes':'High School Student',
       'Music Recording ': 'Music', 'Bio ': 'Math & Sciences', 'Mechanical engineering technology': 'Engineering',
       'Mathematics': 'Math & Sciences', 'Mechanical Engineering': 'Engineering', 'Electronics Engineering': 'Engineering',
       'Mechanical Engineering ': 'Engineering', 'CIS Game Development Option':'Game Development',
       'Finance/Business ':'Business Administration', 'Challenger Program':'Challenger', 'Non Degree seeking': 'Non-degree',
       'Technical Studies, Applied Associate of Science': 'Math & Sciences',
       'Changed to Business ': 'Business Administration', 'Mechanical Engineering Technology': 'Engineering',
       'mechanical engineering technology':'Engineering', 'edam':'Engineering',
       'Share Time Engineering':'Engineering',
       'Engineering Design and Manufacturing (Time Share)':'Engineering', 'Psychology':'Psychology',
       'Undecided':'Undecided', 'dont have one':'Undecided', 'Share time engineering':'Engineering',
       'Highschool dual enrollment program':'High School Student',
       "didn't send professor screenshot": 'Undecided', 'Digital Media Technology':'Arts',
       'Business and Marketing ': 'Business Administiration',
       'Web Development Certificate of Achievement': 'Web Development',
       'Business Professional':'Business Administiration', 'biology': 'Math & Sciences',
       'ShareTime CSIP Program': 'ShareTime CSIP Program',
       'Information Security Certificate of Achievement': 'Information Security',
       'Business Administration':'Business Administration', 'Early Childhood Education': 'Early Childhood Education',
       'Mechanical engineer of technology':'Engineering', 'Political Science ': 'Political Science',
       'Engineering Science': 'Engineering', 'Business Admin':'Business Administration',
       'Mechanical engineering tech':'Engineering', 'MET':'Engineering', 'Business':'Business Administration', 
       'Finance': 'Business Administration',
       'Data Analytics Certificate of Achievement': 'Data Science', 'Economics ': 'Economics',
       'EDAM share time': 'Engineering', 'nursing': 'Nursing',
       'I am a student from MCVTS, and I am doing dual enrollment. ':'High School Student',
       'Mechanical Engineering technology': 'Engineering',
       'Electronic engineering Technology ': 'Engineering', 'EDAM': 'Engineering', 'engineering tech': 'Engineering',
       'Mec Tech': 'Engineering', 'Visiting Student':'Visiting Student', 'Data Science ': 'Data Science',
       'Mech Tech Engineering': 'Engineering', 'edam sharetime': 'Engineering',
       'Electrical Engineering Technology': 'Engineering',
       'Gaining college credits for high school':'High School Student', 'Mech tech ': 'Engineering',
       'Sharetime(EDAM)': 'Engineering', 'Edam': 'Engineering', 'Cybersecurity': 'Cybersecurity',
       'ELECTRONICS ENGINEERING TECHNOLOGY': 'Engineering',
       'ELECTRONICS ENGINEERING TECH': 'Engineering',
       'computer science and digital media technology': 'Computer Science', 'Morris Tech': 'High School Student',
       'Engineering ': 'Engineering', 'Culinary Arts and Science': 'Culinary Arts',
       'mechanical engineering tech. ': 'Engineering',
       'I am a Highschool student and decided to take the course since it was offered to me. ': 'High School Student',
       'Computer Science- Data Science': 'Computer Science', 'mechanical engineering ': 'Engineering',
       'Electrical Engineer': 'Engineering',
       'Information Technology and Information Security Certificate of Achievement': 'Information Technology'
}
computing_selected['Major'] = computing_selected['Major'].map(major_mapping)

# %%
major_mapping = {
    'First Choice': 'First Choice',
    'Business': 'Business',
    'Nursing': 'Nursing',
    'LIberal Arts': 'Liberal Arts',
    'Science': 'Math & Science',
    'did not swap': 'Undecided',
    'Math & Science -> Psychology -> Liberal Arts -> IT': 'Math & Science',
    'Engineering': 'Engineering',
    'Radiography': 'Health Sciences',
    'History': 'History',
    'not majoring': 'Undecided',
    'Criminal Justice ': 'Criminal Justice',
    'I wanted to do computer science but changed to certificate for financial reasons.': 'First Choice',
    'used to be comp sci then switched to IT': 'First Choice',
    'Game Development': 'First Choice',
    'i did not change': 'First Choice',
    'I did not change my major': 'First Choice',
    'Criminal Justice': 'Criminal Justice',
    'Architecture Program': 'Architecture',
    'Computer Science': 'First Choice',
    'Photography': 'Art',
    'no': 'First Choice',
    'Computer programming': 'First Choice',
    'changed from wanting to coach to IT': 'Health Sciences',
    'I have a degree, but wanted to attend ccm courses to get more experience with data analytics.': 'Undecided',
    'Math': 'Math & Science',
    'none': 'Undecided',
    'EDAM sharetime': 'Engineering',
    'first choice': 'First Choice',
    'Biology': 'Math & Science',
    'cybersecurity ': 'First Choice',
    'Mechanical Engineering': 'Engineering',
    'Game Design': 'First Choice',
    'Still majoring in engineering': 'Engineering',
    'Exercise Science': 'Health Sciences',
    'esl': 'Undecided',
    'Cybersecurity ': 'First Choice',
    "I didn't know how to go full into cybersecurity": 'First Choice',
    'crim': 'Criminal Justice',
    'Graphic Design': 'Art',
    'came to ccm undecided for first year': 'Undecided',
    'idk': 'Undecided',
    'Psych': 'Psychology',
    'exercise science': 'Health Sciences'
}
computing_selected['first_major'] = computing_selected['first_major'].map(major_mapping)

# %%
#Let's look at our final dataset
computing_selected.tail()
# Out:
#                 Major  hs_councelor       teacher IT_website    admissions  \
# 448  Computer Science            No            No         No            No
# 449  Computer Science            No            No         No            No
# 450  Computer Science  Don't recall  Don't recall        Yes  Don't recall
# 451  Computer Science            No            No        Yes           Yes
# 452  Game Development           Yes            No         No            No
#
#     CCM_advisor employer ccmworforce njworkforce         other gender  \
# 448          No       No          No          No            No    Man
# 449          No       No          No          No            No    Man
# 450          No       No          No          No           Yes    Man
# 451          No       No          No          No  Don't recall    Man
# 452         Yes       No          No          No            No    Man
#
#              race/ethnicity             age  intereset_rating  \
# ...

# %%
computing_selected.sample(5) #I ran this 3 times and in all iterations, our data looks ready to analyze.
# Out:
#                       Major hs_councelor       teacher IT_website admissions  \
# 255        Computer Science           No           Yes         No         No
# 102  ShareTime CSIP Program           No            No         No         No
# 384        Computer Science           No            No         No         No
# 440        Game Development          Yes  Don't recall         No         No
# 180  Information Technology          Yes           Yes        Yes        Yes
#
#     CCM_advisor employer ccmworforce njworkforce other gender  \
# 255          No       No          No          No    No    Man
# 102          No       No          No          No    No  Woman
# 384          No       No          No          No    No    Man
# 440         Yes       No          No          No    No    Man
# 180         Yes      Yes         Yes         Yes    No    Man
#
#          race/ethnicity             age  intereset_rating   first_major  \
# ...

# %%
#Let's write our dataset into a csv file.
computing_selected.to_csv("cleaned_computingsurvey_data.csv")
